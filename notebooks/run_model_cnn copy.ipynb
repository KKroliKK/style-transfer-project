# %% [markdown]
# # Imports

# %%
import sys

sys.path.append("../src/")

from model_cnn.helpers import image_loader, imshow
from model_cnn.utils import transfer_style

# %% [markdown]
# # Load Data

# %%
style, content, input = image_loader(
    style="../data/malevich.jpg", content="../data/redpanda.jpg", resolution=2560
)

# %%
imshow(style, title="Style Image")
imshow(content, title="Content Image")

# %% [markdown]
# # Style Transfer

# %%
result = transfer_style(style, content, input)
# Out:
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 80.296623 Content Loss: 93.809860
#
# run [100]:
# Style Loss : 52.612560 Content Loss: 87.075813
#
# run [150]:
# Style Loss : 42.315620 Content Loss: 87.230568
#
# run [200]:
# Style Loss : 39.637730 Content Loss: 96.140747
#
# run [250]:
# Style Loss : 32.156391 Content Loss: 96.972641
#
# run [300]:
# Style Loss : 36.307526 Content Loss: 105.149330
#
# 26.77

# %%
imshow(result)
