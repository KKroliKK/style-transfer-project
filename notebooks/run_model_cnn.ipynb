# %% [markdown]
# # Imports

# %%
from src.model_cnn.helpers import image_loader, imshow
from src.model_cnn.utils import transfer_style

# %% [markdown]
# # Load Data

# %%
style, content, input = image_loader(
    style="./data/malevich.jpg", content="./data/redpanda.jpg", resolution=480
)

# %%
imshow(style, title="Style Image")
imshow(content, title="Content Image")

# %% [markdown]
# # Style Transfer

# %%
result = transfer_style(style, content, input)
# Out:
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 156.893341 Content Loss: 243.409088
#
# run [100]:
# Style Loss : 93.264359 Content Loss: 216.579285
#
# run [150]:
# Style Loss : 74.234642 Content Loss: 211.295029
#
# run [200]:
# Style Loss : 65.867760 Content Loss: 210.620026
#
# run [250]:
# Style Loss : 113.148705 Content Loss: 218.486343
#
# run [300]:
# Style Loss : 76.882614 Content Loss: 268.424652
#
# 61.31

# %%
imshow(result)
