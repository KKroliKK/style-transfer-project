# %% [markdown]
# # Imports

# %%
import sys

sys.path.append("../src/")

from model_cnn.helpers import image_loader, imshow
from model_cnn.utils import transfer_style

# %% [markdown]
# # Load Data

# %%
style, content, input = image_loader(
    style="../data/model_cnn/malevich.jpg",
    content="../data/model_cnn/redpanda.jpg",
    resolution=2560,
)

# %%
imshow(style, title="Style Image")
imshow(content, title="Content Image")

# %% [markdown]
# # Style Transfer

# %%
result = transfer_style(style, content, input)
# Out:
# Building the style transfer model..
# c:\Studying\Practical Machine Learning\style-transfer-project\notebooks\../src\model_cnn\image_transformations.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).clone().detach().view(-1, 1, 1)
# c:\Studying\Practical Machine Learning\style-transfer-project\notebooks\../src\model_cnn\image_transformations.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).clone().detach().view(-1, 1, 1)
# Optimizing..
# run [50]:
# Style Loss : 80.564941 Content Loss: 94.198601
#
# run [100]:
# Style Loss : 52.666496 Content Loss: 87.131744
#
# run [150]:
# ...

# %%
imshow(result)
