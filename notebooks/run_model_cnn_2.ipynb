# %%
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

sys.path.append("../src/")

from model_cnn_2.inference import inference

# %% [markdown]
# # Content image

# %%
img = mpimg.imread("../data/model_cnn_2/source/img.png")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Example of styling using each style

# %% [markdown]
# You should set `style_index = -1`

# %%
inference(
    content_file = "../data/model_cnn_2/source/img.png",
    model_path = "../models/model_cnn_2/",
    save_path = "../data/model_cnn_2/inference/",
    style_index = -1
)

# %%
img = mpimg.imread('../data/model_cnn_2/inference/new_images.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Example of styling using specific style

# %% [markdown]
# `style_index` should be from 0-7

# %%
inference(
    content_file = "../data/model_cnn_2/source/img.png",
    model_path = "../models/model_cnn_2/",
    save_path = "../data/model_cnn_2/inference/",
    style_index = 2
)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../data/model_cnn_2/inference/new_images.jpg')
imgplot = plt.imshow(img)
plt.show()
